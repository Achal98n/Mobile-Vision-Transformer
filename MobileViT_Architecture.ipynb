# %% [markdown]
# MobileViT Architecture : Small (_S), Extra Small(_XS) & Extra-Extra small (_XXS)

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import tensorflow as tf
from tensorflow.keras import layers as L


def inverted_residual_block(inputs, num_filters, strides=1, expansion_ratio=1):
    ## Point-Wise Convolution
    x = L.Conv2D(
        filters=expansion_ratio*inputs.shape[-1],
        kernel_size=1,
        padding="same",
        use_bias=False
    )(inputs)
    x = L.BatchNormalization()(x)
    x = L.Activation("swish")(x)

    ## Depth-Wise Convolution
    x = L.DepthwiseConv2D(
        kernel_size=3,
        strides=strides,
        padding="same",
        use_bias=False
    )(x)
    x = L.BatchNormalization()(x)
    x = L.Activation("swish")(x)

    ## Point-Wise Convolution
    x = L.Conv2D(
        filters=num_filters,
        kernel_size=1,
        padding="same",
        use_bias=False
    )(x)
    x = L.BatchNormalization()(x)

    ## Residual Connection
    if strides == 1 and (inputs.shape == x.shape):
        return L.Add()([inputs, x])
    return x


def mlp(x, mlp_dim, dim, dropout_rate=0.1):
    x = L.Dense(mlp_dim, activation="swish")(x)
    x = L.Dropout(dropout_rate)(x)
    x = L.Dense(dim)(x)
    x = L.Dropout(dropout_rate)(x)
    return x

def transformer_encoder(x, num_heads, dim, mlp_dim):
    skip_1 = x
    x = L.LayerNormalization()(x)
    x = L.MultiHeadAttention(
        num_heads=num_heads, key_dim=dim
    )(x, x)
    x = L.Add()([x, skip_1])

    skip_2 = x
    x = L.LayerNormalization()(x)
    x = mlp(x, mlp_dim, dim)
    x = L.Add()([x, skip_2])

    return x

def mobile_vit_block(inputs, num_filters, dim, patch_size=2, num_layers=1):
    B, H, W, C = inputs.shape

    ## 3x3 conv
    x = L.Conv2D(
        filters=C,
        kernel_size=3,
        padding="same",
        use_bias=False
    )(inputs)
    x = L.BatchNormalization()(x)
    x = L.Activation("swish")(x)

    ## 1x1 conv: d-dimension
    x = L.Conv2D(
        filters=dim,
        kernel_size=1,
        padding="same",
        use_bias=False
    )(inputs)
    x = L.BatchNormalization()(x)
    x = L.Activation("swish")(x)

    ## Reshape x to flattened patches
    P = patch_size*patch_size
    N = int(H*W//P)
    x = L.Reshape((P, N, dim))(x)

    ## Transformr Encoder
    for _ in range(num_layers):
        x = transformer_encoder(x, 1, dim, dim*2)

    ## Reshape
    x = L.Reshape((H, W, dim))(x)

    ## 1x1 conv: C-dimension
    x = L.Conv2D(
        filters=C,
        kernel_size=1,
        padding="same",
        use_bias=False
    )(inputs)
    x = L.BatchNormalization()(x)
    x = L.Activation("swish")(x)

    ## Concatenation
    x = L.Concatenate()([x, inputs])

    ## 3x3 conv
    x = L.Conv2D(
        filters=num_filters,
        kernel_size=3,
        padding="same",
        use_bias=False
    )(inputs)
    x = L.BatchNormalization()(x)
    x = L.Activation("swish")(x)

    return x

def MobileViT(input_shape, num_channels, dim, expansion_ratio, num_layers=[2, 4, 3], num_classes=1000):
    ## Input layer
    inputs = L.Input(input_shape)

    ## Stem
    x = L.Conv2D(
        filters=num_channels[0],
        kernel_size=3,
        strides=2,
        padding="same",
        use_bias=False
    )(inputs)
    x = L.BatchNormalization()(x)
    x = L.Activation("swish")(x)
    x = inverted_residual_block(x, num_channels[1], strides=1, expansion_ratio=expansion_ratio)

    ## Stage 1
    x = inverted_residual_block(x, num_channels[2], strides=2, expansion_ratio=expansion_ratio)
    x = inverted_residual_block(x, num_channels[3], strides=1, expansion_ratio=expansion_ratio)
    x = inverted_residual_block(x, num_channels[4], strides=1, expansion_ratio=expansion_ratio)

    ## Stage 2
    x = inverted_residual_block(x, num_channels[5], strides=2, expansion_ratio=expansion_ratio)
    x = mobile_vit_block(x, num_channels[6], dim[0], num_layers=num_layers[0])

    ## Stage 3
    x = inverted_residual_block(x, num_channels[7], strides=2, expansion_ratio=expansion_ratio)
    x = mobile_vit_block(x, num_channels[8], dim[1], num_layers=num_layers[1])

    ## Stage 4
    x = inverted_residual_block(x, num_channels[9], strides=2, expansion_ratio=expansion_ratio)
    x = mobile_vit_block(x, num_channels[10], dim[2], num_layers=num_layers[2])
    x = L.Conv2D(
        filters=num_channels[11],
        kernel_size=1,
        padding="same",
        use_bias=False
    )(x)
    x = L.BatchNormalization()(x)
    x = L.Activation("swish")(x)

    ## Classifier
    x = L.GlobalAveragePooling2D()(x)
    outputs = L.Dense(num_classes, activation="softmax")(x)

    model = tf.keras.models.Model(inputs, outputs)
    return model


def MobileViT_S(input_shape, num_classes):
    num_channels = [16, 32, 64, 64, 64, 96, 144, 128, 192, 160, 240, 640]
    dim = [144, 192, 240]
    expansion_ratio = 4

    return MobileViT(
        input_shape,
        num_channels,
        dim,
        expansion_ratio,
        num_classes=num_classes
    )

def MobileViT_XS(input_shape, num_classes):
    num_channels = [16, 32, 48, 48, 48, 64, 96, 80, 120, 96, 144, 384]
    dim = [96, 120, 144]
    expansion_ratio = 4

    return MobileViT(
        input_shape,
        num_channels,
        dim,
        expansion_ratio,
        num_classes=num_classes
    )

def MobileViT_XXS(input_shape, num_classes):
    num_channels = [16, 16, 24, 24, 24, 48, 64, 64, 80, 80, 96, 320]
    dim = [64, 80, 96]
    expansion_ratio = 2

    return MobileViT(
        input_shape,
        num_channels,
        dim,
        expansion_ratio,
        num_classes=num_classes
    )


if __name__ == "__main__":


    model = MobileViT_XXS((256, 256, 3), 1000)
    model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d_28 (Conv2D)          (None, 128, 128, 16)         432       ['input_2[0][0]']
#
#  batch_normalization_35 (Ba  (None, 128, 128, 16)         64        ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 128, 128, 16)         0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  conv2d_29 (Conv2D)          (None, 128, 128, 32)         512       ['activation_28[0][0]']
#
#  batch_normalization_36 (Ba  (None, 128, 128, 32)         128       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_29 (Activation)  (None, 128, 128, 32)         0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  depthwise_conv2d_7 (Depthw  (None, 128, 128, 32)         288       ['activation_29[0][0]']
#  iseConv2D)
#
#  batch_normalization_37 (Ba  (None, 128, 128, 32)         128       ['depthwise_conv2d_7[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 128, 128, 32)         0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 128, 128, 16)         512       ['activation_30[0][0]']
#
#  batch_normalization_38 (Ba  (None, 128, 128, 16)         64        ['conv2d_30[0][0]']
#  tchNormalization)
#
#  add_21 (Add)                (None, 128, 128, 16)         0         ['activation_28[0][0]',
#                                                                      'batch_normalization_38[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 128, 128, 32)         512       ['add_21[0][0]']
#
#  batch_normalization_39 (Ba  (None, 128, 128, 32)         128       ['conv2d_31[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 128, 128, 32)         0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  depthwise_conv2d_8 (Depthw  (None, 64, 64, 32)           288       ['activation_31[0][0]']
#  iseConv2D)
#
#  batch_normalization_40 (Ba  (None, 64, 64, 32)           128       ['depthwise_conv2d_8[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 64, 64, 32)           0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  conv2d_32 (Conv2D)          (None, 64, 64, 24)           768       ['activation_32[0][0]']
#
#  batch_normalization_41 (Ba  (None, 64, 64, 24)           96        ['conv2d_32[0][0]']
#  tchNormalization)
#
#  conv2d_33 (Conv2D)          (None, 64, 64, 48)           1152      ['batch_normalization_41[0][0]
#                                                                     ']
#
#  batch_normalization_42 (Ba  (None, 64, 64, 48)           192       ['conv2d_33[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 64, 64, 48)           0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  depthwise_conv2d_9 (Depthw  (None, 64, 64, 48)           432       ['activation_33[0][0]']
#  iseConv2D)
#
#  batch_normalization_43 (Ba  (None, 64, 64, 48)           192       ['depthwise_conv2d_9[0][0]']
#  tchNormalization)
#
#  activation_34 (Activation)  (None, 64, 64, 48)           0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  conv2d_34 (Conv2D)          (None, 64, 64, 24)           1152      ['activation_34[0][0]']
#
#  batch_normalization_44 (Ba  (None, 64, 64, 24)           96        ['conv2d_34[0][0]']
#  tchNormalization)
#
#  add_22 (Add)                (None, 64, 64, 24)           0         ['batch_normalization_41[0][0]
#                                                                     ',
#                                                                      'batch_normalization_44[0][0]
#                                                                     ']
#
#  conv2d_35 (Conv2D)          (None, 64, 64, 48)           1152      ['add_22[0][0]']
#
#  batch_normalization_45 (Ba  (None, 64, 64, 48)           192       ['conv2d_35[0][0]']
#  tchNormalization)
#
#  activation_35 (Activation)  (None, 64, 64, 48)           0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  depthwise_conv2d_10 (Depth  (None, 64, 64, 48)           432       ['activation_35[0][0]']
#  wiseConv2D)
#
#  batch_normalization_46 (Ba  (None, 64, 64, 48)           192       ['depthwise_conv2d_10[0][0]']
#  tchNormalization)
#
#  activation_36 (Activation)  (None, 64, 64, 48)           0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 64, 64, 24)           1152      ['activation_36[0][0]']
#
#  batch_normalization_47 (Ba  (None, 64, 64, 24)           96        ['conv2d_36[0][0]']
#  tchNormalization)
#
#  add_23 (Add)                (None, 64, 64, 24)           0         ['add_22[0][0]',
#                                                                      'batch_normalization_47[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 64, 64, 48)           1152      ['add_23[0][0]']
#
#  batch_normalization_48 (Ba  (None, 64, 64, 48)           192       ['conv2d_37[0][0]']
#  tchNormalization)
#
#  activation_37 (Activation)  (None, 64, 64, 48)           0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  depthwise_conv2d_11 (Depth  (None, 32, 32, 48)           432       ['activation_37[0][0]']
#  wiseConv2D)
#
#  batch_normalization_49 (Ba  (None, 32, 32, 48)           192       ['depthwise_conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_38 (Activation)  (None, 32, 32, 48)           0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  conv2d_38 (Conv2D)          (None, 32, 32, 48)           2304      ['activation_38[0][0]']
#
#  batch_normalization_50 (Ba  (None, 32, 32, 48)           192       ['conv2d_38[0][0]']
#  tchNormalization)
#
#  conv2d_42 (Conv2D)          (None, 32, 32, 64)           27648     ['batch_normalization_50[0][0]
#                                                                     ']
#
#  batch_normalization_54 (Ba  (None, 32, 32, 64)           256       ['conv2d_42[0][0]']
#  tchNormalization)
#
#  activation_42 (Activation)  (None, 32, 32, 64)           0         ['batch_normalization_54[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 32, 32, 128)          8192      ['activation_42[0][0]']
#
#  batch_normalization_55 (Ba  (None, 32, 32, 128)          512       ['conv2d_43[0][0]']
#  tchNormalization)
#
#  activation_43 (Activation)  (None, 32, 32, 128)          0         ['batch_normalization_55[0][0]
#                                                                     ']
#
#  depthwise_conv2d_12 (Depth  (None, 16, 16, 128)          1152      ['activation_43[0][0]']
#  wiseConv2D)
#
#  batch_normalization_56 (Ba  (None, 16, 16, 128)          512       ['depthwise_conv2d_12[0][0]']
#  tchNormalization)
#
#  activation_44 (Activation)  (None, 16, 16, 128)          0         ['batch_normalization_56[0][0]
#                                                                     ']
#
#  conv2d_44 (Conv2D)          (None, 16, 16, 64)           8192      ['activation_44[0][0]']
#
#  batch_normalization_57 (Ba  (None, 16, 16, 64)           256       ['conv2d_44[0][0]']
#  tchNormalization)
#
#  conv2d_48 (Conv2D)          (None, 16, 16, 80)           46080     ['batch_normalization_57[0][0]
#                                                                     ']
#
#  batch_normalization_61 (Ba  (None, 16, 16, 80)           320       ['conv2d_48[0][0]']
#  tchNormalization)
#
#  activation_48 (Activation)  (None, 16, 16, 80)           0         ['batch_normalization_61[0][0]
#                                                                     ']
#
#  conv2d_49 (Conv2D)          (None, 16, 16, 160)          12800     ['activation_48[0][0]']
#
#  batch_normalization_62 (Ba  (None, 16, 16, 160)          640       ['conv2d_49[0][0]']
#  tchNormalization)
#
#  activation_49 (Activation)  (None, 16, 16, 160)          0         ['batch_normalization_62[0][0]
#                                                                     ']
#
#  depthwise_conv2d_13 (Depth  (None, 8, 8, 160)            1440      ['activation_49[0][0]']
#  wiseConv2D)
#
#  batch_normalization_63 (Ba  (None, 8, 8, 160)            640       ['depthwise_conv2d_13[0][0]']
#  tchNormalization)
#
#  activation_50 (Activation)  (None, 8, 8, 160)            0         ['batch_normalization_63[0][0]
#                                                                     ']
#
#  conv2d_50 (Conv2D)          (None, 8, 8, 80)             12800     ['activation_50[0][0]']
#
#  batch_normalization_64 (Ba  (None, 8, 8, 80)             320       ['conv2d_50[0][0]']
#  tchNormalization)
#
#  conv2d_54 (Conv2D)          (None, 8, 8, 96)             69120     ['batch_normalization_64[0][0]
#                                                                     ']
#
#  batch_normalization_68 (Ba  (None, 8, 8, 96)             384       ['conv2d_54[0][0]']
#  tchNormalization)
#
#  activation_54 (Activation)  (None, 8, 8, 96)             0         ['batch_normalization_68[0][0]
#                                                                     ']
#
#  conv2d_55 (Conv2D)          (None, 8, 8, 320)            30720     ['activation_54[0][0]']
#
#  batch_normalization_69 (Ba  (None, 8, 8, 320)            1280      ['conv2d_55[0][0]']
#  tchNormalization)
#
#  activation_55 (Activation)  (None, 8, 8, 320)            0         ['batch_normalization_69[0][0]
#                                                                     ']
#
#  global_average_pooling2d_1  (None, 320)                  0         ['activation_55[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_37 (Dense)            (None, 1000)                 321000    ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 559208 (2.13 MB)
# Trainable params: 555512 (2.12 MB)
# Non-trainable params: 3696 (14.44 KB)
# __________________________________________________________________________________________________
